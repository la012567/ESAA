# %%
import pandas as pd
titanic_df = pd.read_csv('titanic_train.csv')  
# 같은 디렉토리 경로가 아니라면 (r'C:\Users\Owner\Desktop\ESAA\titanic_train.csv')로 지정해야 함
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
print('titanic 변수 type:', type(titanic_df))
print('DataFrame 크기:', titanic_df.shape)
titanic_df
# Out:
# titanic 변수 type: <class 'pandas.core.frame.DataFrame'>
# DataFrame 크기: (891, 12)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.info()
print('\n')
value_counts = titanic_df['Pclass'].value_counts()
print(value_counts)
print('\n')
titanic_pclass = titanic_df['Pclass']
print(type(titanic_pclass))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
#
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#
#
# <class 'pandas.core.series.Series'>

# %%
titanic_pclass.head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass, dtype: int64

# %% [markdown]
# #### 데이터 셀렉션 및 필터링

# %%
# 데이터 셀렉션 및 필터링

print('단일 칼럼 데이터 추출:\n', titanic_df['Pclass'].head(3))
print('\n 여러 칼럼의 데이터 추출:\n', titanic_df[['Survived', 'Pclass']].head(3))
# print('[] 안에 숫자 index는 keyerror 오류 발생:\n', titanic_df[0])
# dataframe 뒤의 [] 에는 칼럼명이 들어가야 함
# Out:
# 단일 칼럼 데이터 추출:
#  0    3
# 1    1
# 2    3
# Name: Pclass, dtype: int64
#
#  여러 칼럼의 데이터 추출:
#     Survived  Pclass
# 0         0       3
# 1         1       1
# 2         1       3

# %%
titanic_df[0:2] # 인덱스 형태로 변환 가능한 표현식은 입력 가능. 슬라이싱 사용 가능
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic_df[titanic_df['Pclass'] == 3].head(3)
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 0            1         0       3   Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3    Heikkinen, Miss. Laina  female  26.0
# 4            5         0       3  Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 2      0      0  STON/O2. 3101282  7.925   NaN        S
# 4      0      0            373450  8.050   NaN        S

# %%
# ix[] 연산자 .. 는 사라졌다

print('칼럼 위치 기반 인덱싱 데이터 추출:', titanic_df.iloc[0,2]) # 칼럼 위치 기반 : iloc()
print('칼럼 명 기반 인덱싱 데이터 추출:', titanic_df.loc[0, 'Pclass']) # 칼럼 명칭 기반 : loc()
# Out:
# 칼럼 위치 기반 인덱싱 데이터 추출: 3
# 칼럼 명 기반 인덱싱 데이터 추출: 3

# %%
data = {'Name': ['Chulmin', 'Eunkyung', 'Jinwoong', 'Soobeom'],
        'Year': [2011, 2016, 2015, 2015],
        'Gender': ['Male', 'Female', 'Male', 'Male']
       }
data_df = pd.DataFrame(data, index=['one','two','three','four'])
data_df
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# four    Soobeom  2015    Male

# %%
# data_df를 reset_index()로 새로운 숫자형 인덱스 생성
data_df_reset = data_df.reset_index()
data_df_reset = data_df_reset.rename(columns={'index':'old_index'})

# 인덱스값에 1을 더해서 1부터 시작하는 새로운 인덱스값 생성
data_df_reset.index = data_df_reset.index + 1
data_df_reset
#ix[] 를 쓸 때는 행 위치에 적용되는 인덱스값과 위치 기반 인덱싱이 integer일 때
# 혼선을 주기 때문에 iloc[]/loc[] 으로 바뀜
# 혼선을 주는 예시 : ix[1,1] = 'chulmin' (첫번째 행이 인덱스값 1이 되었으므로)
# Out:
#   old_index      Name  Year  Gender
# 1       one   Chulmin  2011    Male
# 2       two  Eunkyung  2016  Female
# 3     three  Jinwoong  2015    Male
# 4      four   Soobeom  2015    Male

# %%
# iloc[] : 위치 기반 인덱싱

data_df.iloc[0,0] # 첫번째 행, 열의 데이터/ (0,0)의 위치
#data_df.iloc[0,'Name'] 은 오류를 일으킨다. 위치 인덱싱이 아닌 명칭을 입력했기 때문에
#data_df.iloc['one',0] 문자열 인덱스를 행 위치에 입력해도 오류 발생
# Out:
# 'Chulmin'

# %%
data_df_reset.iloc[0,1]
# Out:
# 'Chulmin'

# %%
# loc[] : 명칭 기반 인덱싱
data_df.loc['one','Name'] #인덱스값이 'one', 칼럼명이 'Name'
# Out:
# 'Chulmin'

# %%
data_df_reset.loc[1,'Name'] #index가 숫자형일 수 있다
# data_df_reset.loc[0,'Name'] 은 인덱스값이 0인 행이 없으므로 오류를 일으킨다
# Out:
# 'Chulmin'

# %%
print('위치 기반 iloc slicing\n', data_df.iloc[0:1,0],'\n') # 0부터 0까지 (종료값 포함x)
print('명칭 기반 loc slicing\n', data_df.loc['one':'two','Name'],'\n') # 'one'부터 'two'까지 (종료값 포함)

print(data_df_reset.loc[1:2,'Name']) # 정수형 인덱스라도 명칭 기반 인덱싱이라 2까지 반환
# Out:
# 위치 기반 iloc slicing
#  one    Chulmin
# Name: Name, dtype: object
#
# 명칭 기반 loc slicing
#  one     Chulmin
# two    Eunkyung
# Name: Name, dtype: object
#
# 1     Chulmin
# 2    Eunkyung
# Name: Name, dtype: object

# %%
titanic_df = pd.read_csv('titanic_train.csv')
titanic_boolean = titanic_df[titanic_df['Age']>60]
print(type(titanic_boolean))
titanic_boolean
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# ...

# %%
titanic_df[titanic_df['Age']>60][['Name','Age']].head(3) # 불린 인덱싱 사용
# Out:
#                               Name   Age
# 33           Wheadon, Mr. Edward H  66.0
# 54  Ostby, Mr. Engelhart Cornelius  65.0
# 96       Goldschmidt, Mr. George B  71.0

# %%
titanic_df.loc[titanic_df['Age']>60, ['Name', 'Age']].head(3) # loc 사용, ['Name', 'Age']는 칼럼 위치에
# Out:
#                               Name   Age
# 33           Wheadon, Mr. Edward H  66.0
# 54  Ostby, Mr. Engelhart Cornelius  65.0
# 96       Goldschmidt, Mr. George B  71.0

# %%
titanic_df[(titanic_df['Age']>60) & (titanic_df['Pclass']==1)&
          (titanic_df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 275  female  63.0      1      0   13502  77.9583    D7        S
# 829  female  62.0      0      0  113572  80.0000   B28      NaN

# %%
cond1 = titanic_df['Age']>60
cond2 = titanic_df['Pclass']==1
cond3 = titanic_df['Sex']=='female'
titanic_df[cond1 & cond2 & cond3]

# 개별 조건을 변수에 할당하고 변수를 결합해서 불린 인덱싱 수행
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 275  female  63.0      1      0   13502  77.9583    D7        S
# 829  female  62.0      0      0  113572  80.0000   B28      NaN

# %% [markdown]
# #### 정렬, Aggregation 함수, Groupby 적용

# %%
# 정렬, Aggregation 함수, GroupBy 적용

titanic_sorted = titanic_df.sort_values(by=['Name']) #sort_values() : dataframe / series의 정렬
titanic_sorted.head(3)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 845          846         0       3               Abbing, Mr. Anthony    male
# 746          747         0       3       Abbott, Mr. Rossmore Edward    male
# 279          280         1       3  Abbott, Mrs. Stanton (Rosa Hunt)  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  35.0      1      1  C.A. 2673  20.25   NaN        S

# %%
titanic_sorted = titanic_df.sort_values(by=['Pclass', 'Name'], ascending=False)
# 여러 개의 칼럼으로 정렬하기 : by에 리스트 형식으로 
# ascending = False : 내림차순 정렬
titanic_sorted.head(3)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 868          869         0       3      van Melkebeke, Mr. Philemon  male
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
# 282          283         0       3        de Pelsmaeker, Mr. Alfons  male
#
#       Age  SibSp  Parch    Ticket  Fare Cabin Embarked
# 868   NaN      0      0    345777   9.5   NaN        S
# 153  40.5      0      2  A/5. 851  14.5   NaN        S
# 282  16.0      0      0    345778   9.5   NaN        S

# %%
# Aggregation 함수 적용 : 모든 칼럼에 aggregation 적용
titanic_df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# 특정 칼럼에 aggregation 적용하기 위해서는 대상 칼럼들만 추출
titanic_df[['Age','Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
# groupby() 적용

titanic_groupby = titanic_df.groupby(by='Pclass')
print(type(titanic_groupby))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
# groupby() 대상 칼럼을 제외하고 모든 칼럼에 aggregation

titanic_groupby = titanic_df.groupby('Pclass').count()
titanic_groupby
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
titanic_groupby = titanic_df.groupby('Pclass')[['PassengerId', 'Survived']].count()
titanic_groupby
# Out:
#         PassengerId  Survived
# Pclass
# 1               216       216
# 2               184       184
# 3               491       491

# %%
titanic_df.groupby('Pclass')['Age'].agg([max,min])
# Out:
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %%
# 여러 개의 칼럼이 서로 다른 aggregation 적용

agg_format = {'Age':'max', 'SibSp':'sum','Fare':'mean'} #딕셔너리 이용
titanic_df.groupby('Pclass').agg(agg_format)
# Out:
#          Age  SibSp       Fare
# Pclass
# 1       80.0     90  84.154687
# 2       70.0     74  20.662183
# 3       74.0    302  13.675550

# %% [markdown]
# #### 결손 데이터 처리하기

# %%
# 결손 데이터 처리하기

# isna() : 결손 데이터 여부 확인
titanic_df.isna().head(3)
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False

# %%
titanic_df.isna().sum() # 결손데이터의 개수 구하기 (true는 1, false는 0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# fillna() : 결손 데이터 대체하기

titanic_df['Cabin']= titanic_df['Cabin'].fillna('C000')
titanic_df.head(3)

# 실제 데이터 세트 값을 변경하려면
# titanic_df['Cabin']=titanic_df['Cabin'].fillna('C000') : 반환값을 다시 반환변숫값으로 지정하거나
# inplace=True를 쓰면 된다
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  C000        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C000        S

# %%
titanic_df['Age'] = titanic_df['Age'].fillna(titanic_df['Age'].mean()) # Age의 Nan값은 평균나이로 지정
titanic_df['Embraked'] = titanic_df['Embarked'].fillna('S') # Embarked의 Nan값은 S로 지정
titanic_df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# Embraked       0
# dtype: int64

# %% [markdown]
# #### apply lambda 식으로 데이터 가공

# %%
# apply lambda 식으로 데이터 가공

def get_square(a):
    return a**2

print('3의 제곱은:', get_square(3))

# lambda : 함수의 선언과 함수 내의 처리를 한 줄의 식으로 쉽게 변환하는 것
lambda_square = lambda x : x**2 # :의 왼쪽에 x는 입력인자, 오른쪽은 입력인자의 계산식(반환값)
print('3의 제곱은:', lambda_square(3))

# 여러 개의 값을 입력인자로 사용할 경우 : map()

a= [1,2,3]
squares= map(lambda x : x**2, a) #map()
list(squares)
# Out:
# 3의 제곱은: 9
# 3의 제곱은: 9
# [1, 4, 9]

# %%
titanic_df['Name_len']= titanic_df['Name'].apply(lambda x : len(x)) #name 칼럼의 문자열 개수를 name_len에
titanic_df[['Name', 'Name_len']].head(3)
# Out:
#                                                 Name  Name_len
# 0                            Braund, Mr. Owen Harris        23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51
# 2                             Heikkinen, Miss. Laina        22

# %%
titanic_df['Child_Adult']=titanic_df['Age'].apply(lambda x : 'Child' if x <15 else 'Adult')
# age가 15세 미만이면 child, 그렇지 않으면 adult 로 구분하는 child_adult
titanic_df[['Age', 'Child_Adult']].head(8)
# Out:
#          Age Child_Adult
# 0  22.000000       Adult
# 1  38.000000       Adult
# 2  26.000000       Adult
# 3  35.000000       Adult
# 4  35.000000       Adult
# 5  29.699118       Adult
# 6  54.000000       Adult
# 7   2.000000       Child

# %%
titanic_df['Age_cat']= titanic_df['Age'].apply(lambda x : 'Child' if x<=15 else ('Adult' if x<=60 else 'Elderly' ))
titanic_df['Age_cat'].value_counts()

# else if 사용하지 않는 대신
# else() 로 묶어서 사용
# 이 경우에도 if 절의 경우 반환값이 식보다 먼저 나온다
# Out:
# Adult      786
# Child       83
# Elderly     22
# Name: Age_cat, dtype: int64

# %%
# switch case문처럼 else if가 많이 필요한 경우 
# 나이에 따라 세분화된 분류를 수행하는 함수 생성
def get_category(age):
    cat= ''
    if age <=5: cat = 'Baby'
    elif age <=12: cat = 'Child'
    elif age <=18: cat = 'Teenager'
    elif age <=25: cat = 'Student'
    elif age <=35: cat = 'Young Adult'
    elif age <=60: cat = 'Adult'
    else: cat = 'Elderly'
        
    return cat

# lambda 식에 위에서 생성한 get_category()함수를 반환값으로 지정
# get_category(x)는 입력값으로 'Age' 칼럼 값을 받아서 해당하는 cat 반환
titanic_df['Age_cat']= titanic_df['Age'].apply(lambda x : get_category(x))
titanic_df[['Age', 'Age_cat']].head()
# Out:
#     Age      Age_cat
# 0  22.0      Student
# 1  38.0        Adult
# 2  26.0  Young Adult
# 3  35.0  Young Adult
# 4  35.0  Young Adult
